# %% [markdown]
# * user should install dependencies (with pip, conda, whatever you're using)
#     * magforce
#     * magpylib
#     * numpy
#     * matplotlib

# %% [markdown]
# * importing packages

# %%
from numpy import linspace, pi
from matplotlib.pyplot import show, figure
from matplotlib import rcParams
from magpylib.source.magnet import Cylinder
from magpylib import Collection, displaySystem

from magforce import plot_1D_along_x, plot_1D_along_y, plot_1D_along_z
from magforce import plot_2D_plane_x, plot_2D_plane_y, plot_2D_plane_z
from magforce import plot_3D

# %% [markdown]
# * setting up figure size for notebook

# %%
# make figures bigger on notebook
width = 7
height = 7
rcParams['figure.figsize'] = [width, height]

# %% [markdown]
# * defining a cobalt spherical sample, with 4mm diameter, Ms of 1.4e6 A/m and demagnetizing factor of 1/3
#
# * the sample variable needs to be a dictionary for magforce's functions to work, and it must include the 'demagnetizing_factor', 'volume' and 'M_saturation' keys

# %%
demagnetizing_factor = 1/3             # sphere
volume = 4 / 3 * pi * (4 / 1000) ** 3  # V sphere r=4mm [m3]
M_saturation = 1.400e6                 # Ms Co room temperature [A/m]

sample = {'demagnetizing_factor': demagnetizing_factor, 
          'volume': volume, 
          'M_saturation': M_saturation}

# %% [markdown]
# * defining a magnet collection
#     * it consists of a single cylinder with a 5mm diameter and 20mm height
#     * its top surface is at z = 0
#     * the my_collection is a magpylib.Collection instance (see [magpylib](https://magpylib.readthedocs.io/en/latest/) for more information)

# %%
m1 = Cylinder(mag=[0, 0, 1000], 
              dim=[5, 20], 
              pos=[0, 0, -10])

my_collection = Collection(m1)

# %% [markdown]
# * displaying the collection

# %%
collection_fig = figure(num='System Display')
collection_ax = collection_fig.add_subplot(projection='3d')

displaySystem(my_collection, 
              direc=True, 
              markers=[(0, 0, 0)], 
              suppress=False, 
              subplotAx=collection_ax)

# %% [markdown]
# * plotting 1D along x
#   * x from -30 to 30 , 1000 points
#   * y = 0
#   * z = 0

# %%
# Plotting 1D along x

plot_1D_along_x(xs = linspace(-30, 30, 1000), 
                y = 0, 
                z = 0, 
                collection = my_collection, 
                sample = sample, 
                BF = 'BF', 
                saveCSV = False)
# Out:
# c:\users\mateu\appdata\local\programs\python\python37\lib\site-packages\magpylib\_lib\fields\PM_Cylinder.py:93: RuntimeWarning: Warning: getB Position directly on magnet surface
#   warn('Warning: getB Position directly on magnet surface', RuntimeWarning)
# c:\users\mateu\appdata\local\programs\python\python37\lib\site-packages\magpylib\_lib\fields\PM_Cylinder.py:93: RuntimeWarning: Warning: getB Position directly on magnet surface
#   warn('Warning: getB Position directly on magnet surface', RuntimeWarning)

# %% [markdown]
# * plotting 1D along y
#   * x = 0
#   * y from -30 to 30 , 1000 points
#   * z = 0

# %%
# Plotting 1D along y

plot_1D_along_y(x = 0, 
                ys = linspace(-30, 30, 1000), 
                z = 0, 
                collection = my_collection, 
                sample = sample, 
                BF = 'BF', 
                saveCSV = False)
# Out:
# c:\users\mateu\appdata\local\programs\python\python37\lib\site-packages\magpylib\_lib\fields\PM_Cylinder.py:93: RuntimeWarning: Warning: getB Position directly on magnet surface
#   warn('Warning: getB Position directly on magnet surface', RuntimeWarning)
# c:\users\mateu\appdata\local\programs\python\python37\lib\site-packages\magpylib\_lib\fields\PM_Cylinder.py:93: RuntimeWarning: Warning: getB Position directly on magnet surface
#   warn('Warning: getB Position directly on magnet surface', RuntimeWarning)

# %% [markdown]
# * plotting 1D along z
#   * x = 0
#   * y = 0
#   * z from 0 to 30 , 1000 points

# %%
# Plotting 1D along z

plot_1D_along_z(x = 0, 
                y = 0, 
                zs = linspace(0, 30, 1000), 
                collection = my_collection, 
                sample = sample, 
                BF = 'BF', 
                saveCSV = False)
# Out:
# c:\users\mateu\appdata\local\programs\python\python37\lib\site-packages\magpylib\_lib\fields\PM_Cylinder.py:93: RuntimeWarning: Warning: getB Position directly on magnet surface
#   warn('Warning: getB Position directly on magnet surface', RuntimeWarning)
# c:\users\mateu\appdata\local\programs\python\python37\lib\site-packages\magpylib\_lib\fields\PM_Cylinder.py:93: RuntimeWarning: Warning: getB Position directly on magnet surface
#   warn('Warning: getB Position directly on magnet surface', RuntimeWarning)

# %% [markdown]
# * plotting 2D on x plane
#   * x = 0
#   * y from -30 to 30 , 35 points
#   * z from 0 to 30 , 35 points

# %%
# Plotting 2D on x

plot_2D_plane_x(x = 0, 
                ys = linspace(-30, 30, 35), 
                zs = linspace(0, 30, 35), 
                collection = my_collection, 
                sample = sample, 
                modes = ['stream', 'quiver', 'surface'], 
                BF = 'BF', 
                saveCSV = False)
# Out:
# c:\users\mateu\appdata\local\programs\python\python37\lib\site-packages\magpylib\_lib\fields\PM_Cylinder.py:93: RuntimeWarning: Warning: getB Position directly on magnet surface
#   warn('Warning: getB Position directly on magnet surface', RuntimeWarning)
# c:\users\mateu\appdata\local\programs\python\python37\lib\site-packages\magforce\plotting.py:673: UserWarning: Z contains NaN values. This may result in rendering artifacts.
#   ax_B_surf_x.plot_surface(POSy, POSz, Bfieldx)
# c:\users\mateu\appdata\local\programs\python\python37\lib\site-packages\magforce\plotting.py:679: UserWarning: Z contains NaN values. This may result in rendering artifacts.
#   ax_B_surf_y.plot_surface(POSy, POSz, Bfieldy)
# c:\users\mateu\appdata\local\programs\python\python37\lib\site-packages\magforce\plotting.py:685: UserWarning: Z contains NaN values. This may result in rendering artifacts.
#   ax_B_surf_z.plot_surface(POSy, POSz, Bfieldz)
# c:\users\mateu\appdata\local\programs\python\python37\lib\site-packages\magforce\plotting.py:739: UserWarning: Z contains NaN values. This may result in rendering artifacts.
#   ax_F_surf_x.plot_surface(POSy, POSz, FORx)
# c:\users\mateu\appdata\local\programs\python\python37\lib\site-packages\magforce\plotting.py:745: UserWarning: Z contains NaN values. This may result in rendering artifacts.
#   ax_F_surf_y.plot_surface(POSy, POSz, FORy)
# c:\users\mateu\appdata\local\programs\python\python37\lib\site-packages\magforce\plotting.py:751: UserWarning: Z contains NaN values. This may result in rendering artifacts.
#   ax_F_surf_z.plot_surface(POSy, POSz, FORz)

# %% [markdown]
# * plotting 2D on y plane
#   * x from -30 to 30 , 35 points
#   * y = 0
#   * z from 0 to 30 , 35 points

# %%
# Plotting 2D on y

plot_2D_plane_y(xs = linspace(-30, 30, 35), 
                y = 0, 
                zs = linspace(0, 30, 35), 
                collection = my_collection, 
                sample = sample, 
                modes = ['stream', 'quiver', 'surface'], 
                BF = 'BF', 
                saveCSV = False)
# Out:
# c:\users\mateu\appdata\local\programs\python\python37\lib\site-packages\magforce\plotting.py:911: UserWarning: Z contains NaN values. This may result in rendering artifacts.
#   ax_B_surf_x.plot_surface(POSx, POSz, Bfieldx)
# c:\users\mateu\appdata\local\programs\python\python37\lib\site-packages\magforce\plotting.py:917: UserWarning: Z contains NaN values. This may result in rendering artifacts.
#   ax_B_surf_y.plot_surface(POSx, POSz, Bfieldy)
# c:\users\mateu\appdata\local\programs\python\python37\lib\site-packages\magforce\plotting.py:923: UserWarning: Z contains NaN values. This may result in rendering artifacts.
#   ax_B_surf_z.plot_surface(POSx, POSz, Bfieldz)
# c:\users\mateu\appdata\local\programs\python\python37\lib\site-packages\magforce\plotting.py:977: UserWarning: Z contains NaN values. This may result in rendering artifacts.
#   ax_F_surf_x.plot_surface(POSx, POSz, FORx)
# c:\users\mateu\appdata\local\programs\python\python37\lib\site-packages\magforce\plotting.py:983: UserWarning: Z contains NaN values. This may result in rendering artifacts.
#   ax_F_surf_y.plot_surface(POSx, POSz, FORy)
# c:\users\mateu\appdata\local\programs\python\python37\lib\site-packages\magforce\plotting.py:989: UserWarning: Z contains NaN values. This may result in rendering artifacts.
#   ax_F_surf_z.plot_surface(POSx, POSz, FORz)

# %% [markdown]
# * plotting 2D on z plane
#   * x from -30 to 30 , 35 points
#   * y from -30 to 30 , 35 points
#   * z = 0

# %%
# Plotting 2D on z

plot_2D_plane_z(xs = linspace(-30, 30, 35), 
                ys = linspace(-30, 30, 35), 
                z = 0, 
                collection = my_collection, 
                sample = sample, 
                modes = ['stream', 'quiver', 'surface'], 
                BF = 'BF', 
                saveCSV = False)
# Out:
# c:\users\mateu\appdata\local\programs\python\python37\lib\site-packages\magforce\plotting.py:1149: UserWarning: Z contains NaN values. This may result in rendering artifacts.
#   ax_B_surf_x.plot_surface(POSx, POSy, Bfieldx)
# c:\users\mateu\appdata\local\programs\python\python37\lib\site-packages\magforce\plotting.py:1155: UserWarning: Z contains NaN values. This may result in rendering artifacts.
#   ax_B_surf_y.plot_surface(POSx, POSy, Bfieldy)
# c:\users\mateu\appdata\local\programs\python\python37\lib\site-packages\magforce\plotting.py:1161: UserWarning: Z contains NaN values. This may result in rendering artifacts.
#   ax_B_surf_z.plot_surface(POSx, POSy, Bfieldz)
# c:\users\mateu\appdata\local\programs\python\python37\lib\site-packages\magforce\plotting.py:1215: UserWarning: Z contains NaN values. This may result in rendering artifacts.
#   ax_F_surf_x.plot_surface(POSx, POSy, FORx)
# c:\users\mateu\appdata\local\programs\python\python37\lib\site-packages\magforce\plotting.py:1221: UserWarning: Z contains NaN values. This may result in rendering artifacts.
#   ax_F_surf_y.plot_surface(POSx, POSy, FORy)
# c:\users\mateu\appdata\local\programs\python\python37\lib\site-packages\magforce\plotting.py:1227: UserWarning: Z contains NaN values. This may result in rendering artifacts.
#   ax_F_surf_z.plot_surface(POSx, POSy, FORz)

# %% [markdown]
# * plotting 3D
#   * x from -30 to 30 , 7 points
#   * y from -30 to 30 , 7 points
#   * z from 0 to 30 , 7 points

# %%
# Plotting 3D

plot_3D(xs = linspace(-30, 30, 7), 
        ys = linspace(-30, 30, 7), 
        zs = linspace(0, 30, 7), 
        collection = my_collection, 
        sample = sample, 
        BF = 'BF', 
        saveCSV = False)
# Out:
# c:\users\mateu\appdata\local\programs\python\python37\lib\site-packages\mpl_toolkits\mplot3d\axes3d.py:2594: RuntimeWarning: invalid value encountered in greater
#   mask = norm > 0
